# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing dataset

# %%
df = pd.read_csv('training_data.csv')

# %%
# understanding data

# %%
df.head()
# Out:
#    claim_number  age_of_driver gender  marital_status  safty_rating  \
# 0             1             46      M             1.0            85
# 1             3             21      F             0.0            75
# 2             4             49      F             0.0            87
# 3             5             58      F             1.0            58
# 4             6             38      M             1.0            95
#
#    annual_income  high_education_ind  address_change_ind living_status  \
# 0          38301                   1                   1          Rent
# 1          30445                   0                   1          Rent
# 2          38923                   0                   1           Own
# 3          40605                   1                   0           Own
# 4          36380                   1                   0          Rent
#
#    zip_code  ... liab_prct channel policy_report_filed_ind  claim_est_payout  \
# 0     80006  ...        74  Broker                       0       7530.940993
# 1     15021  ...        79  Online                       0       2966.024895
# 2     20158  ...         0  Broker                       0       6283.888333
# 3     15024  ...        99  Broker                       1       6169.747994
# 4     50034  ...         7  Broker                       0       4541.387150
#
#    age_of_vehicle  vehicle_category vehicle_price  vehicle_color  \
# 0             9.0           Compact   12885.45235          white
# 1             4.0             Large   29429.45218          white
# 2             3.0           Compact   21701.18195          white
# 3             4.0            Medium   13198.27344          other
# 4             7.0            Medium   38060.21122           gray
#
#    vehicle_weight  fraud
# 0     16161.33381      0
# 1     28691.96422      0
# 2     22090.94758      1
# 3     38329.58106      1
# 4     25876.56319      0
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#        claim_number  age_of_driver gender  marital_status  safty_rating  \
# 17993         29993             69      M             1.0            93
# 17994         29996             35      F             0.0            22
# 17995         29997             27      F             1.0            81
# 17996         29999             52      F             1.0            86
# 17997         30000             61      F             0.0            60
#
#        annual_income  high_education_ind  address_change_ind living_status  \
# 17993          42338                   1                   0           Own
# 17994          35579                   1                   1           Own
# 17995          32953                   0                   1          Rent
# 17996          39519                   1                   0           Own
# 17997          41126                   1                   0          Rent
#
#        zip_code  ... liab_prct channel policy_report_filed_ind  \
# 17993     15012  ...        99  Broker                       0
# 17994     20111  ...        94   Phone                       1
# 17995     15012  ...         1  Online                       1
# 17996     15026  ...        75  Broker                       1
# 17997     50001  ...        35   Phone                       0
#
#        claim_est_payout  age_of_vehicle  vehicle_category vehicle_price  \
# 17993       4806.841803             6.0            Medium  32144.571850
# 17994       4089.794471             3.0            Medium   9468.510601
# 17995       2225.803056             5.0            Medium  64974.369590
# 17996       9560.744844             3.0           Compact  24983.268110
# 17997       5166.915270             5.0            Medium  19295.970480
#
#        vehicle_color  vehicle_weight  fraud
# 17993          black     16868.53410      0
# 17994           blue     31500.99689      1
# 17995          black     44536.25506      0
# 17996          white     50093.75959      0
# 17997           blue     15257.21450      0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (17998, 25)

# %%
df.describe()
# Out:
#        claim_number  age_of_driver  marital_status  safty_rating  \
# count  17998.000000   17998.000000    17993.000000  17998.000000
# mean   14970.601622      43.695466        0.712722     73.562951
# std     8659.940765      11.959819        0.452505     15.346807
# min        1.000000      18.000000        0.000000      1.000000
# 25%     7479.250000      35.000000        0.000000     65.000000
# 50%    14965.500000      43.000000        1.000000     76.000000
# 75%    22467.750000      51.000000        1.000000     85.000000
# max    30000.000000     229.000000        1.000000    100.000000
#
#        annual_income  high_education_ind  address_change_ind      zip_code  \
# count   17998.000000        17998.000000        17998.000000  17998.000000
# mean    37367.655684            0.699189            0.577286  49875.595955
# std      2957.297249            0.458623            0.494004  29214.655149
# min        -1.000000            0.000000            0.000000      0.000000
# 25%     35554.000000            0.000000            0.000000  20111.000000
# 50%     37610.000000            1.000000            1.000000  50028.000000
# 75%     39318.000000            1.000000            1.000000  80038.000000
# max     54333.000000            1.000000            1.000000  85083.000000
#
#        past_num_of_claims  witness_present_ind     liab_prct  \
# count        17998.000000         17866.000000  17998.000000
# mean             0.505001             0.232677     49.423269
# std              0.955504             0.422550     33.678470
# min              0.000000             0.000000      0.000000
# 25%              0.000000             0.000000     17.000000
# 50%              0.000000             0.000000     50.000000
# 75%              1.000000             0.000000     81.000000
# max              6.000000             1.000000    100.000000
#
#        policy_report_filed_ind  claim_est_payout  age_of_vehicle  \
# count             17998.000000      17981.000000    17990.000000
# mean                  0.600678       4975.792083        5.008060
# std                   0.489773       2215.706510        2.258391
# min                   0.000000        282.639432        0.000000
# 25%                   0.000000       3337.029436        3.000000
# 50%                   1.000000       4668.796318        5.000000
# 75%                   1.000000       6255.901066        6.000000
# max                   1.000000      17218.345010       16.000000
#
#        vehicle_price  vehicle_weight         fraud
# count   17998.000000    17998.000000  17998.000000
# mean    23089.123114    23031.322385      0.156462
# std     11988.429767    12052.385584      0.363303
# min      2457.329316     2429.429302      0.000000
# 25%     14279.574850    14164.122133      0.000000
# 50%     20948.879250    20838.150260      0.000000
# 75%     29562.232780    29430.446293      0.000000
# max    127063.506000   123016.650400      1.000000

# %%
df.columns
# Out:
# Index(['claim_number', 'age_of_driver', 'gender', 'marital_status',
#        'safty_rating', 'annual_income', 'high_education_ind',
#        'address_change_ind', 'living_status', 'zip_code', 'claim_date',
#        'claim_day_of_week', 'accident_site', 'past_num_of_claims',
#        'witness_present_ind', 'liab_prct', 'channel',
#        'policy_report_filed_ind', 'claim_est_payout', 'age_of_vehicle',
#        'vehicle_category', 'vehicle_price', 'vehicle_color', 'vehicle_weight',
#        'fraud'],
#       dtype='object')

# %%
# checking unique values

# %%
df.nunique()
# Out:
# claim_number               17998
# age_of_driver                 87
# gender                         2
# marital_status                 2
# safty_rating                 100
# annual_income               2693
# high_education_ind             2
# address_change_ind             2
# living_status                  2
# zip_code                     276
# claim_date                   731
# claim_day_of_week              7
# accident_site                  3
# past_num_of_claims             7
# witness_present_ind            2
# liab_prct                    101
# channel                        3
# policy_report_filed_ind        2
# claim_est_payout           17981
# age_of_vehicle                17
# vehicle_category               3
# vehicle_price              17998
# vehicle_color                  7
# vehicle_weight             17998
# fraud                          2
# dtype: int64

# %%
df['vehicle_category'].unique()
# Out:
# array(['Compact', 'Large', 'Medium'], dtype=object)

# %%
df['accident_site'].unique()
# Out:
# array(['Local', 'Highway', 'Parking Lot'], dtype=object)

# %%
df['address_change_ind'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df['past_num_of_claims'].unique()
# Out:
# array([1, 0, 3, 5, 2, 4, 6], dtype=int64)

# %%
df['living_status'].unique()
# Out:
# array(['Rent', 'Own'], dtype=object)

# %%
# checking null values

# %%
df.isnull().sum()
# Out:
# claim_number                 0
# age_of_driver                0
# gender                       0
# marital_status               5
# safty_rating                 0
# annual_income                0
# high_education_ind           0
# address_change_ind           0
# living_status                0
# zip_code                     0
# claim_date                   0
# claim_day_of_week            0
# accident_site                0
# past_num_of_claims           0
# witness_present_ind        132
# liab_prct                    0
# channel                      0
# policy_report_filed_ind      0
# claim_est_payout            17
# age_of_vehicle               8
# vehicle_category             0
# vehicle_price                0
# vehicle_color                0
# vehicle_weight               0
# fraud                        0
# dtype: int64

# %%
# handling missing data

# %%
# Determining data missingness

# %%
# Check for MCAR (Missing Completely At Random - data is missing at random, not in a systematic way or showing a pattern)
# Check for MAR (Missing At Random - data is missing in a random way, either it was collected that way, or the data missingness is correlated 
# to other variables)
# Check for MNAR (Missing Not At Random - data is missing due to some unknown reason)

# %%
# Since we have a very small amount of missing data, and missingness is of MCAR type, we will use Complete Case Analysis,i.e. remove all 
# missing values in every row.

# %%
df.sample(10)
# Out:
#        claim_number  age_of_driver gender  marital_status  safty_rating  \
# 627            1034             42      F             1.0            86
# 12870         21420             43      M             1.0            61
# 12798         21298             23      F             1.0            84
# 12553         20880             59      F             1.0            77
# 16617         27737             51      M             0.0            77
# 2043           3394             25      M             0.0            64
# 12470         20729             55      F             1.0            10
# 9120          15170             60      M             1.0            84
# 13900         23103             24      M             1.0            92
# 6998          11605             26      M             0.0            76
#
#        annual_income  high_education_ind  address_change_ind living_status  \
# 627            37383                   1                   0          Rent
# 12870          37599                   1                   1           Own
# 12798          31361                   1                   0          Rent
# 12553          40772                   0                   0           Own
# 16617          39315                   1                   1          Rent
# 2043           32195                   1                   1          Rent
# 12470          40088                   1                   1          Rent
# 9120           40956                   1                   0           Own
# 13900          31787                   1                   1          Rent
# 6998           32605                   1                   1          Rent
#
#        zip_code  ... liab_prct channel policy_report_filed_ind  \
# 627       50054  ...        42  Broker                       1
# 12870     85029  ...        49   Phone                       1
# 12798     85076  ...         5  Online                       0
# 12553     80005  ...        74   Phone                       1
# 16617     50020  ...         2  Online                       1
# 2043      15010  ...        35  Online                       1
# 12470     80022  ...        49  Broker                       0
# 9120      50047  ...        98   Phone                       1
# 13900     20120  ...        99  Online                       0
# 6998      80027  ...        45   Phone                       0
#
#        claim_est_payout  age_of_vehicle  vehicle_category vehicle_price  \
# 627         5628.795971             6.0           Compact   11923.99177
# 12870       7730.042081             2.0           Compact   23653.06485
# 12798       2671.208825             6.0            Medium   16836.18087
# 12553       3291.253091             2.0             Large   20605.31826
# 16617       5040.871044             3.0             Large   18780.05038
# 2043        3963.086571             5.0            Medium   12281.73260
# 12470       6594.578558             7.0            Medium   26569.52092
# 9120        4699.733481             6.0           Compact   21492.36305
# 13900       3943.761140             2.0            Medium   17465.36393
# 6998        7401.780817             6.0             Large   38115.67961
#
#        vehicle_color  vehicle_weight  fraud
# 627            black     9576.897568      1
# 12870           gray    23576.044570      1
# 12798          black    17123.154130      0
# 12553         silver    27256.434180      0
# 16617           blue    25492.034210      0
# 2043           black    30038.797980      0
# 12470            red     8494.607106      0
# 9120          silver    28411.239840      0
# 13900         silver    19969.966090      0
# 6998             red    36333.046170      0
#
# [10 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17998 entries, 0 to 17997
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   claim_number             17998 non-null  int64
#  1   age_of_driver            17998 non-null  int64
#  2   gender                   17998 non-null  object
#  3   marital_status           17993 non-null  float64
#  4   safty_rating             17998 non-null  int64
#  5   annual_income            17998 non-null  int64
#  6   high_education_ind       17998 non-null  int64
#  7   address_change_ind       17998 non-null  int64
#  8   living_status            17998 non-null  object
#  9   zip_code                 17998 non-null  int64
#  10  claim_date               17998 non-null  object
#  11  claim_day_of_week        17998 non-null  object
#  12  accident_site            17998 non-null  object
#  13  past_num_of_claims       17998 non-null  int64
#  14  witness_present_ind      17866 non-null  float64
#  15  liab_prct                17998 non-null  int64
#  16  channel                  17998 non-null  object
#  17  policy_report_filed_ind  17998 non-null  int64
#  18  claim_est_payout         17981 non-null  float64
#  19  age_of_vehicle           17990 non-null  float64
#  20  vehicle_category         17998 non-null  object
#  21  vehicle_price            17998 non-null  float64
#  22  vehicle_color            17998 non-null  object
#  23  vehicle_weight           17998 non-null  float64
#  24  fraud                    17998 non-null  int64
# dtypes: float64(6), int64(11), object(8)
# memory usage: 3.4+ MB

# %%
import missingno as mno
mno.matrix(df, figsize = (20,6))
plt.show()

# %%
df.describe().T
# Out:
#                            count          mean           std          min  \
# claim_number             17998.0  14970.601622   8659.940765     1.000000
# age_of_driver            17998.0     43.695466     11.959819    18.000000
# marital_status           17993.0      0.712722      0.452505     0.000000
# safty_rating             17998.0     73.562951     15.346807     1.000000
# annual_income            17998.0  37367.655684   2957.297249    -1.000000
# high_education_ind       17998.0      0.699189      0.458623     0.000000
# address_change_ind       17998.0      0.577286      0.494004     0.000000
# zip_code                 17998.0  49875.595955  29214.655149     0.000000
# past_num_of_claims       17998.0      0.505001      0.955504     0.000000
# witness_present_ind      17866.0      0.232677      0.422550     0.000000
# liab_prct                17998.0     49.423269     33.678470     0.000000
# policy_report_filed_ind  17998.0      0.600678      0.489773     0.000000
# claim_est_payout         17981.0   4975.792083   2215.706510   282.639432
# age_of_vehicle           17990.0      5.008060      2.258391     0.000000
# vehicle_price            17998.0  23089.123114  11988.429767  2457.329316
# vehicle_weight           17998.0  23031.322385  12052.385584  2429.429302
# fraud                    17998.0      0.156462      0.363303     0.000000
#
#                                   25%           50%           75%  \
# claim_number              7479.250000  14965.500000  22467.750000
# age_of_driver               35.000000     43.000000     51.000000
# marital_status               0.000000      1.000000      1.000000
# safty_rating                65.000000     76.000000     85.000000
# annual_income            35554.000000  37610.000000  39318.000000
# high_education_ind           0.000000      1.000000      1.000000
# address_change_ind           0.000000      1.000000      1.000000
# zip_code                 20111.000000  50028.000000  80038.000000
# past_num_of_claims           0.000000      0.000000      1.000000
# witness_present_ind          0.000000      0.000000      0.000000
# liab_prct                   17.000000     50.000000     81.000000
# policy_report_filed_ind      0.000000      1.000000      1.000000
# claim_est_payout          3337.029436   4668.796318   6255.901066
# age_of_vehicle               3.000000      5.000000      6.000000
# vehicle_price            14279.574850  20948.879250  29562.232780
# vehicle_weight           14164.122133  20838.150260  29430.446293
# fraud                        0.000000      0.000000      0.000000
#
#                                   max
# claim_number              30000.00000
# age_of_driver               229.00000
# marital_status                1.00000
# safty_rating                100.00000
# annual_income             54333.00000
# high_education_ind            1.00000
# address_change_ind            1.00000
# zip_code                  85083.00000
# past_num_of_claims            6.00000
# witness_present_ind           1.00000
# liab_prct                   100.00000
# policy_report_filed_ind       1.00000
# claim_est_payout          17218.34501
# age_of_vehicle               16.00000
# vehicle_price            127063.50600
# vehicle_weight           123016.65040
# fraud                         1.00000

# %%
# descriptive statistics of object columns

# %%
df.describe(include=['O']).T
# Out:
#                    count unique        top  freq
# gender             17998      2          M  9414
# living_status      17998      2        Own  9969
# claim_date         17998    731  9/14/2016    39
# claim_day_of_week  17998      7   Saturday  2630
# accident_site      17998      3      Local  8768
# channel            17998      3     Broker  9633
# vehicle_category   17998      3    Compact  6063
# vehicle_color      17998      7      black  2620

# %%
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Implementing Complete Case Analysis

# %%
cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols
# Out:
# ['marital_status', 'witness_present_ind', 'claim_est_payout', 'age_of_vehicle']

# %%
df.sample(10)
# Out:
#        claim_number  age_of_driver gender  marital_status  safty_rating  \
# 4775           7916             42      F             1.0            89
# 17918         29850             92      F             1.0            69
# 14509         24134             44      M             0.0            92
# 10354         17229             46      F             0.0            74
# 4349           7221             51      F             1.0            99
# 7746          12870             47      F             1.0            67
# 9462          15736             52      M             1.0            58
# 1457           2405             34      M             1.0            85
# 8090          13431             55      F             0.0            77
# 9668          16082             53      M             0.0            60
#
#        annual_income  high_education_ind  address_change_ind living_status  \
# 4775           37367                   0                   0           Own
# 17918          45228                   1                   0           Own
# 14509          37852                   0                   0           Own
# 10354          38280                   1                   1          Rent
# 4349           39307                   0                   1           Own
# 7746           38487                   1                   1           Own
# 9462           39516                   0                   1           Own
# 1457           35256                   0                   1          Rent
# 8090           40070                   1                   0           Own
# 9668           39692                   1                   1          Rent
#
#        zip_code  ... liab_prct channel policy_report_filed_ind  \
# 4775      80028  ...        56  Online                       1
# 17918     50005  ...        23  Broker                       1
# 14509     20113  ...         8  Broker                       1
# 10354     20151  ...        90   Phone                       1
# 4349      85020  ...        93  Broker                       0
# 7746      50021  ...         1  Online                       1
# 9462      15009  ...        60  Broker                       1
# 1457      50009  ...        50  Broker                       1
# 8090      80025  ...        85  Broker                       1
# 9668      15022  ...        98  Broker                       0
#
#        claim_est_payout  age_of_vehicle  vehicle_category vehicle_price  \
# 4775        1300.012960             3.0             Large  22273.540780
# 17918       6908.244615             4.0           Compact  14289.228340
# 14509       2902.378801             4.0            Medium  30054.685890
# 10354       6162.269287             7.0             Large  15216.235620
# 4349        7010.360133             2.0             Large   7382.340954
# 7746        1686.375210             5.0            Medium  33163.562170
# 9462        4641.618316             8.0           Compact  51075.574390
# 1457        5007.766434             4.0            Medium  41385.718310
# 8090        7723.158316             6.0             Large  15496.597260
# 9668        5739.878534             7.0           Compact   7845.036703
#
#        vehicle_color  vehicle_weight  fraud
# 4775           other    24906.199210      0
# 17918          white    31054.173670      0
# 14509          other    21985.323030      0
# 10354          other    12807.678990      0
# 4349           other    21983.382400      0
# 7746           white    15778.307730      0
# 9462           other    36558.572960      0
# 1457           black    44003.852560      0
# 8090            gray    23880.801990      0
# 9668            blue     4557.299303      0
#
# [10 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# claim_number               0.0
# age_of_driver              0.0
# gender                     0.0
# marital_status             0.0
# safty_rating               0.0
# annual_income              0.0
# high_education_ind         0.0
# address_change_ind         0.0
# living_status              0.0
# zip_code                   0.0
# claim_date                 0.0
# claim_day_of_week          0.0
# accident_site              0.0
# past_num_of_claims         0.0
# witness_present_ind        0.0
# liab_prct                  0.0
# channel                    0.0
# policy_report_filed_ind    0.0
# claim_est_payout           0.0
# age_of_vehicle             0.0
# vehicle_category           0.0
# vehicle_price              0.0
# vehicle_color              0.0
# vehicle_weight             0.0
# fraud                      0.0
# dtype: float64

# %%
cols
# Out:
# ['marital_status', 'witness_present_ind', 'claim_est_payout', 'age_of_vehicle']

# %%
# dropping all rows with any null values

# %%
new_df = df.dropna()

# %%
new_df.shape
# Out:
# (17836, 25)

# %%
new_df.isnull().sum()
# Out:
# claim_number               0
# age_of_driver              0
# gender                     0
# marital_status             0
# safty_rating               0
# annual_income              0
# high_education_ind         0
# address_change_ind         0
# living_status              0
# zip_code                   0
# claim_date                 0
# claim_day_of_week          0
# accident_site              0
# past_num_of_claims         0
# witness_present_ind        0
# liab_prct                  0
# channel                    0
# policy_report_filed_ind    0
# claim_est_payout           0
# age_of_vehicle             0
# vehicle_category           0
# vehicle_price              0
# vehicle_color              0
# vehicle_weight             0
# fraud                      0
# dtype: int64

# %%
mno.matrix(new_df, figsize = (20,6))
plt.show()

# %%
# Checking distributions of the original and edited dataset

# %%
df.hist(bins=50, density=True, figsize = (12,12))
plt.show()

# %%
new_df.hist(bins=50, density=True, color = 'red', figsize = (12,12))
plt.show()
